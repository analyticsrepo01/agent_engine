# %%
# !pip install google-cloud-aiplatform[adk,agent_engines]
# Out:
# DEPRECATION: Loading egg at /opt/conda/envs/py312/lib/python3.12/site-packages/setuptools-80.8.0-py3.12.egg is deprecated. pip 25.1 will enforce this behaviour change. A possible replacement is to use pip for package installation. Discussion can be found at https://github.com/pypa/pip/issues/12330
# DEPRECATION: Loading egg at /opt/conda/envs/py312/lib/python3.12/site-packages/bitsandbytes-0.46.0.dev0-py3.12-linux-x86_64.egg is deprecated. pip 25.1 will enforce this behaviour change. A possible replacement is to use pip for package installation. Discussion can be found at https://github.com/pypa/pip/issues/12330
# Requirement already satisfied: google-cloud-aiplatform[adk,agent_engines] in /home/jupyter/.local/lib/python3.12/site-packages (1.94.0)
# Requirement already satisfied: google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,<3.0.0,>=1.34.1 in /opt/conda/envs/py312/lib/python3.12/site-packages (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,<3.0.0,>=1.34.1->google-cloud-aiplatform[adk,agent_engines]) (2.24.2)
# Requirement already satisfied: google-auth<3.0.0,>=2.14.1 in /opt/conda/envs/py312/lib/python3.12/site-packages (from google-cloud-aiplatform[adk,agent_engines]) (2.38.0)
# Requirement already satisfied: proto-plus<2.0.0,>=1.22.3 in /opt/conda/envs/py312/lib/python3.12/site-packages (from google-cloud-aiplatform[adk,agent_engines]) (1.26.1)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<7.0.0,>=3.20.2 in /opt/conda/envs/py312/lib/python3.12/site-packages (from google-cloud-aiplatform[adk,agent_engines]) (4.25.8)
# Requirement already satisfied: packaging>=14.3 in /opt/conda/envs/py312/lib/python3.12/site-packages (from google-cloud-aiplatform[adk,agent_engines]) (24.2)
# Requirement already satisfied: google-cloud-storage<3.0.0,>=1.32.0 in /home/jupyter/.local/lib/python3.12/site-packages (from google-cloud-aiplatform[adk,agent_engines]) (2.19.0)
# Requirement already satisfied: google-cloud-bigquery!=3.20.0,<4.0.0,>=1.15.0 in /home/jupyter/.local/lib/python3.12/site-packages (from google-cloud-aiplatform[adk,agent_engines]) (3.13.0)
# Requirement already satisfied: google-cloud-resource-manager<3.0.0,>=1.3.3 in /home/jupyter/.local/lib/python3.12/site-packages (from google-cloud-aiplatform[adk,agent_engines]) (1.10.4)
# Requirement already satisfied: shapely<3.0.0 in /home/jupyter/.local/lib/python3.12/site-packages (from google-cloud-aiplatform[adk,agent_engines]) (2.0.2)
# Requirement already satisfied: google-genai<2.0.0,>=1.0.0 in /opt/conda/envs/py312/lib/python3.12/site-packages (from google-cloud-aiplatform[adk,agent_engines]) (1.16.1)
# Requirement already satisfied: pydantic<3 in /opt/conda/envs/py312/lib/python3.12/site-packages (from google-cloud-aiplatform[adk,agent_engines]) (2.10.6)
# Requirement already satisfied: typing-extensions in /opt/conda/envs/py312/lib/python3.12/site-packages (from google-cloud-aiplatform[adk,agent_engines]) (4.13.2)
# Requirement already satisfied: docstring-parser<1 in /opt/conda/envs/py312/lib/python3.12/site-packages (from google-cloud-aiplatform[adk,agent_engines]) (0.16)
# Collecting google-adk<1.0.0,>=0.0.2 (from google-cloud-aiplatform[adk,agent_engines])
#   Using cached google_adk-0.5.0-py3-none-any.whl.metadata (9.7 kB)
# Collecting cloudpickle<4.0,>=3.0 (from google-cloud-aiplatform[adk,agent_engines])
#   Downloading cloudpickle-3.1.1-py3-none-any.whl.metadata (7.1 kB)
# Collecting google-cloud-trace<2 (from google-cloud-aiplatform[adk,agent_engines])
#   Downloading google_cloud_trace-1.16.2-py3-none-any.whl.metadata (9.7 kB)
# Collecting google-cloud-logging<4 (from google-cloud-aiplatform[adk,agent_engines])
#   Using cached google_cloud_logging-3.12.1-py2.py3-none-any.whl.metadata (5.0 kB)
# Requirement already satisfied: opentelemetry-sdk<2 in /opt/conda/envs/py312/lib/python3.12/site-packages (from google-cloud-aiplatform[adk,agent_engines]) (1.33.1)
# Collecting opentelemetry-exporter-gcp-trace<2 (from google-cloud-aiplatform[adk,agent_engines])
#   Using cached opentelemetry_exporter_gcp_trace-1.9.0-py3-none-any.whl.metadata (3.3 kB)
# Collecting pydantic<3 (from google-cloud-aiplatform[adk,agent_engines])
#   Downloading pydantic-2.11.7-py3-none-any.whl.metadata (67 kB)
# Collecting authlib>=1.5.1 (from google-adk<1.0.0,>=0.0.2->google-cloud-aiplatform[adk,agent_engines])
#   Downloading authlib-1.6.0-py2.py3-none-any.whl.metadata (4.1 kB)
# Requirement already satisfied: click>=8.1.8 in /opt/conda/envs/py312/lib/python3.12/site-packages (from google-adk<1.0.0,>=0.0.2->google-cloud-aiplatform[adk,agent_engines]) (8.1.8)
# Requirement already satisfied: fastapi>=0.115.0 in /opt/conda/envs/py312/lib/python3.12/site-packages (from google-adk<1.0.0,>=0.0.2->google-cloud-aiplatform[adk,agent_engines]) (0.115.9)
# Collecting google-api-python-client>=2.157.0 (from google-adk<1.0.0,>=0.0.2->google-cloud-aiplatform[adk,agent_engines])
#   Downloading google_api_python_client-2.173.0-py3-none-any.whl.metadata (7.0 kB)
# Collecting google-cloud-secret-manager>=2.22.0 (from google-adk<1.0.0,>=0.0.2->google-cloud-aiplatform[adk,agent_engines])
#   Downloading google_cloud_secret_manager-2.24.0-py3-none-any.whl.metadata (9.7 kB)
# Collecting google-cloud-speech>=2.30.0 (from google-adk<1.0.0,>=0.0.2->google-cloud-aiplatform[adk,agent_engines])
#   Downloading google_cloud_speech-2.33.0-py3-none-any.whl.metadata (9.6 kB)
# Collecting graphviz>=0.20.2 (from google-adk<1.0.0,>=0.0.2->google-cloud-aiplatform[adk,agent_engines])
#   Downloading graphviz-0.21-py3-none-any.whl.metadata (12 kB)
# Collecting mcp>=1.5.0 (from google-adk<1.0.0,>=0.0.2->google-cloud-aiplatform[adk,agent_engines])
#   Downloading mcp-1.9.4-py3-none-any.whl.metadata (28 kB)
# Requirement already satisfied: opentelemetry-api>=1.31.0 in /opt/conda/envs/py312/lib/python3.12/site-packages (from google-adk<1.0.0,>=0.0.2->google-cloud-aiplatform[adk,agent_engines]) (1.33.1)
# Requirement already satisfied: python-dotenv>=1.0.0 in /opt/conda/envs/py312/lib/python3.12/site-packages (from google-adk<1.0.0,>=0.0.2->google-cloud-aiplatform[adk,agent_engines]) (1.0.1)
# Requirement already satisfied: PyYAML>=6.0.2 in /opt/conda/envs/py312/lib/python3.12/site-packages (from google-adk<1.0.0,>=0.0.2->google-cloud-aiplatform[adk,agent_engines]) (6.0.2)
# Requirement already satisfied: sqlalchemy>=2.0 in /opt/conda/envs/py312/lib/python3.12/site-packages (from google-adk<1.0.0,>=0.0.2->google-cloud-aiplatform[adk,agent_engines]) (2.0.41)
# Collecting tzlocal>=5.3 (from google-adk<1.0.0,>=0.0.2->google-cloud-aiplatform[adk,agent_engines])
#   Using cached tzlocal-5.3.1-py3-none-any.whl.metadata (7.6 kB)
# Requirement already satisfied: uvicorn>=0.34.0 in /opt/conda/envs/py312/lib/python3.12/site-packages (from google-adk<1.0.0,>=0.0.2->google-cloud-aiplatform[adk,agent_engines]) (0.34.2)
# Requirement already satisfied: googleapis-common-protos<2.0.0,>=1.56.2 in /opt/conda/envs/py312/lib/python3.12/site-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,<3.0.0,>=1.34.1->google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,<3.0.0,>=1.34.1->google-cloud-aiplatform[adk,agent_engines]) (1.70.0)
# Requirement already satisfied: requests<3.0.0,>=2.18.0 in /opt/conda/envs/py312/lib/python3.12/site-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,<3.0.0,>=1.34.1->google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,<3.0.0,>=1.34.1->google-cloud-aiplatform[adk,agent_engines]) (2.32.3)
# Requirement already satisfied: grpcio<2.0dev,>=1.33.2 in /opt/conda/envs/py312/lib/python3.12/site-packages (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,<3.0.0,>=1.34.1->google-cloud-aiplatform[adk,agent_engines]) (1.71.0)
# Requirement already satisfied: grpcio-status<2.0.dev0,>=1.33.2 in /home/jupyter/.local/lib/python3.12/site-packages (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,<3.0.0,>=1.34.1->google-cloud-aiplatform[adk,agent_engines]) (1.63.0rc1)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /opt/conda/envs/py312/lib/python3.12/site-packages (from google-auth<3.0.0,>=2.14.1->google-cloud-aiplatform[adk,agent_engines]) (5.5.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /home/jupyter/.local/lib/python3.12/site-packages (from google-auth<3.0.0,>=2.14.1->google-cloud-aiplatform[adk,agent_engines]) (0.3.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in /home/jupyter/.local/lib/python3.12/site-packages (from google-auth<3.0.0,>=2.14.1->google-cloud-aiplatform[adk,agent_engines]) (4.9)
# Requirement already satisfied: google-cloud-core<3.0.0dev,>=1.6.0 in /opt/conda/envs/py312/lib/python3.12/site-packages (from google-cloud-bigquery!=3.20.0,<4.0.0,>=1.15.0->google-cloud-aiplatform[adk,agent_engines]) (2.4.3)
# Requirement already satisfied: google-resumable-media<3.0dev,>=0.6.0 in /home/jupyter/.local/lib/python3.12/site-packages (from google-cloud-bigquery!=3.20.0,<4.0.0,>=1.15.0->google-cloud-aiplatform[adk,agent_engines]) (2.7.2)
# Requirement already satisfied: python-dateutil<3.0dev,>=2.7.2 in /opt/conda/envs/py312/lib/python3.12/site-packages (from google-cloud-bigquery!=3.20.0,<4.0.0,>=1.15.0->google-cloud-aiplatform[adk,agent_engines]) (2.9.0.post0)
# Collecting google-cloud-appengine-logging<2.0.0,>=0.1.3 (from google-cloud-logging<4->google-cloud-aiplatform[adk,agent_engines])
#   Downloading google_cloud_appengine_logging-1.6.2-py3-none-any.whl.metadata (9.9 kB)
# Collecting google-cloud-audit-log<1.0.0,>=0.3.1 (from google-cloud-logging<4->google-cloud-aiplatform[adk,agent_engines])
#   Using cached google_cloud_audit_log-0.3.2-py3-none-any.whl.metadata (9.0 kB)
# Requirement already satisfied: grpc-google-iam-v1<1.0.0,>=0.12.4 in /home/jupyter/.local/lib/python3.12/site-packages (from google-cloud-logging<4->google-cloud-aiplatform[adk,agent_engines]) (0.12.7)
# Requirement already satisfied: google-crc32c<2.0dev,>=1.0 in /home/jupyter/.local/lib/python3.12/site-packages (from google-cloud-storage<3.0.0,>=1.32.0->google-cloud-aiplatform[adk,agent_engines]) (1.5.0)
# Requirement already satisfied: anyio<5.0.0,>=4.8.0 in /opt/conda/envs/py312/lib/python3.12/site-packages (from google-genai<2.0.0,>=1.0.0->google-cloud-aiplatform[adk,agent_engines]) (4.9.0)
# Requirement already satisfied: httpx<1.0.0,>=0.28.1 in /opt/conda/envs/py312/lib/python3.12/site-packages (from google-genai<2.0.0,>=1.0.0->google-cloud-aiplatform[adk,agent_engines]) (0.28.1)
# Requirement already satisfied: websockets<15.1.0,>=13.0.0 in /opt/conda/envs/py312/lib/python3.12/site-packages (from google-genai<2.0.0,>=1.0.0->google-cloud-aiplatform[adk,agent_engines]) (15.0.1)
# Collecting opentelemetry-resourcedetector-gcp==1.*,>=1.5.0dev0 (from opentelemetry-exporter-gcp-trace<2->google-cloud-aiplatform[adk,agent_engines])
#   Using cached opentelemetry_resourcedetector_gcp-1.9.0a0-py3-none-any.whl.metadata (2.4 kB)
# Requirement already satisfied: opentelemetry-semantic-conventions==0.54b1 in /opt/conda/envs/py312/lib/python3.12/site-packages (from opentelemetry-sdk<2->google-cloud-aiplatform[adk,agent_engines]) (0.54b1)
# Requirement already satisfied: deprecated>=1.2.6 in /opt/conda/envs/py312/lib/python3.12/site-packages (from opentelemetry-api>=1.31.0->google-adk<1.0.0,>=0.0.2->google-cloud-aiplatform[adk,agent_engines]) (1.2.18)
# Requirement already satisfied: importlib-metadata<8.7.0,>=6.0 in /opt/conda/envs/py312/lib/python3.12/site-packages (from opentelemetry-api>=1.31.0->google-adk<1.0.0,>=0.0.2->google-cloud-aiplatform[adk,agent_engines]) (8.6.1)
# Requirement already satisfied: annotated-types>=0.6.0 in /opt/conda/envs/py312/lib/python3.12/site-packages (from pydantic<3->google-cloud-aiplatform[adk,agent_engines]) (0.7.0)
# Collecting pydantic-core==2.33.2 (from pydantic<3->google-cloud-aiplatform[adk,agent_engines])
#   Downloading pydantic_core-2.33.2-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (6.8 kB)
# Requirement already satisfied: typing-inspection>=0.4.0 in /opt/conda/envs/py312/lib/python3.12/site-packages (from pydantic<3->google-cloud-aiplatform[adk,agent_engines]) (0.4.1)
# Requirement already satisfied: numpy>=1.14 in /opt/conda/envs/py312/lib/python3.12/site-packages (from shapely<3.0.0->google-cloud-aiplatform[adk,agent_engines]) (2.2.4)
# Requirement already satisfied: idna>=2.8 in /opt/conda/envs/py312/lib/python3.12/site-packages (from anyio<5.0.0,>=4.8.0->google-genai<2.0.0,>=1.0.0->google-cloud-aiplatform[adk,agent_engines]) (3.10)
# Requirement already satisfied: sniffio>=1.1 in /opt/conda/envs/py312/lib/python3.12/site-packages (from anyio<5.0.0,>=4.8.0->google-genai<2.0.0,>=1.0.0->google-cloud-aiplatform[adk,agent_engines]) (1.3.1)
# Requirement already satisfied: cryptography in /opt/conda/envs/py312/lib/python3.12/site-packages (from authlib>=1.5.1->google-adk<1.0.0,>=0.0.2->google-cloud-aiplatform[adk,agent_engines]) (45.0.2)
# Requirement already satisfied: starlette<0.46.0,>=0.40.0 in /opt/conda/envs/py312/lib/python3.12/site-packages (from fastapi>=0.115.0->google-adk<1.0.0,>=0.0.2->google-cloud-aiplatform[adk,agent_engines]) (0.45.3)
# Collecting httplib2<1.0.0,>=0.19.0 (from google-api-python-client>=2.157.0->google-adk<1.0.0,>=0.0.2->google-cloud-aiplatform[adk,agent_engines])
#   Using cached httplib2-0.22.0-py3-none-any.whl.metadata (2.6 kB)
# Collecting google-auth-httplib2<1.0.0,>=0.2.0 (from google-api-python-client>=2.157.0->google-adk<1.0.0,>=0.0.2->google-cloud-aiplatform[adk,agent_engines])
#   Using cached google_auth_httplib2-0.2.0-py2.py3-none-any.whl.metadata (2.2 kB)
# Collecting uritemplate<5,>=3.0.1 (from google-api-python-client>=2.157.0->google-adk<1.0.0,>=0.0.2->google-cloud-aiplatform[adk,agent_engines])
#   Downloading uritemplate-4.2.0-py3-none-any.whl.metadata (2.6 kB)
# Collecting grpc-google-iam-v1<1.0.0,>=0.12.4 (from google-cloud-logging<4->google-cloud-aiplatform[adk,agent_engines])
#   Downloading grpc_google_iam_v1-0.14.2-py3-none-any.whl.metadata (9.1 kB)
# Requirement already satisfied: certifi in /opt/conda/envs/py312/lib/python3.12/site-packages (from httpx<1.0.0,>=0.28.1->google-genai<2.0.0,>=1.0.0->google-cloud-aiplatform[adk,agent_engines]) (2025.1.31)
# Requirement already satisfied: httpcore==1.* in /opt/conda/envs/py312/lib/python3.12/site-packages (from httpx<1.0.0,>=0.28.1->google-genai<2.0.0,>=1.0.0->google-cloud-aiplatform[adk,agent_engines]) (1.0.7)
# Requirement already satisfied: h11<0.15,>=0.13 in /opt/conda/envs/py312/lib/python3.12/site-packages (from httpcore==1.*->httpx<1.0.0,>=0.28.1->google-genai<2.0.0,>=1.0.0->google-cloud-aiplatform[adk,agent_engines]) (0.14.0)
# Requirement already satisfied: httpx-sse>=0.4 in /opt/conda/envs/py312/lib/python3.12/site-packages (from mcp>=1.5.0->google-adk<1.0.0,>=0.0.2->google-cloud-aiplatform[adk,agent_engines]) (0.4.0)
# Requirement already satisfied: pydantic-settings>=2.5.2 in /opt/conda/envs/py312/lib/python3.12/site-packages (from mcp>=1.5.0->google-adk<1.0.0,>=0.0.2->google-cloud-aiplatform[adk,agent_engines]) (2.9.1)
# Collecting python-multipart>=0.0.9 (from mcp>=1.5.0->google-adk<1.0.0,>=0.0.2->google-cloud-aiplatform[adk,agent_engines])
#   Downloading python_multipart-0.0.20-py3-none-any.whl.metadata (1.8 kB)
# Collecting sse-starlette>=1.6.1 (from mcp>=1.5.0->google-adk<1.0.0,>=0.0.2->google-cloud-aiplatform[adk,agent_engines])
#   Downloading sse_starlette-2.3.6-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: pyasn1<0.6.0,>=0.4.6 in /home/jupyter/.local/lib/python3.12/site-packages (from pyasn1-modules>=0.2.1->google-auth<3.0.0,>=2.14.1->google-cloud-aiplatform[adk,agent_engines]) (0.5.1)
# Requirement already satisfied: six>=1.5 in /opt/conda/envs/py312/lib/python3.12/site-packages (from python-dateutil<3.0dev,>=2.7.2->google-cloud-bigquery!=3.20.0,<4.0.0,>=1.15.0->google-cloud-aiplatform[adk,agent_engines]) (1.17.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/conda/envs/py312/lib/python3.12/site-packages (from requests<3.0.0,>=2.18.0->google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,<3.0.0,>=1.34.1->google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,<3.0.0,>=1.34.1->google-cloud-aiplatform[adk,agent_engines]) (3.4.1)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/conda/envs/py312/lib/python3.12/site-packages (from requests<3.0.0,>=2.18.0->google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,<3.0.0,>=1.34.1->google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,<3.0.0,>=1.34.1->google-cloud-aiplatform[adk,agent_engines]) (2.3.0)
# Requirement already satisfied: greenlet>=1 in /opt/conda/envs/py312/lib/python3.12/site-packages (from sqlalchemy>=2.0->google-adk<1.0.0,>=0.0.2->google-cloud-aiplatform[adk,agent_engines]) (3.2.2)
# Requirement already satisfied: wrapt<2,>=1.10 in /opt/conda/envs/py312/lib/python3.12/site-packages (from deprecated>=1.2.6->opentelemetry-api>=1.31.0->google-adk<1.0.0,>=0.0.2->google-cloud-aiplatform[adk,agent_engines]) (1.17.2)
# Collecting pyparsing!=3.0.0,!=3.0.1,!=3.0.2,!=3.0.3,<4,>=2.4.2 (from httplib2<1.0.0,>=0.19.0->google-api-python-client>=2.157.0->google-adk<1.0.0,>=0.0.2->google-cloud-aiplatform[adk,agent_engines])
#   Using cached pyparsing-3.2.3-py3-none-any.whl.metadata (5.0 kB)
# Requirement already satisfied: zipp>=3.20 in /opt/conda/envs/py312/lib/python3.12/site-packages (from importlib-metadata<8.7.0,>=6.0->opentelemetry-api>=1.31.0->google-adk<1.0.0,>=0.0.2->google-cloud-aiplatform[adk,agent_engines]) (3.21.0)
# Requirement already satisfied: cffi>=1.14 in /opt/conda/envs/py312/lib/python3.12/site-packages (from cryptography->authlib>=1.5.1->google-adk<1.0.0,>=0.0.2->google-cloud-aiplatform[adk,agent_engines]) (1.17.1)
# Requirement already satisfied: pycparser in /opt/conda/envs/py312/lib/python3.12/site-packages (from cffi>=1.14->cryptography->authlib>=1.5.1->google-adk<1.0.0,>=0.0.2->google-cloud-aiplatform[adk,agent_engines]) (2.22)
# Downloading cloudpickle-3.1.1-py3-none-any.whl (20 kB)
# Using cached google_adk-0.5.0-py3-none-any.whl (1.2 MB)
# Using cached google_cloud_logging-3.12.1-py2.py3-none-any.whl (229 kB)
# Downloading google_cloud_trace-1.16.2-py3-none-any.whl (103 kB)
# Using cached opentelemetry_exporter_gcp_trace-1.9.0-py3-none-any.whl (13 kB)
# Using cached opentelemetry_resourcedetector_gcp-1.9.0a0-py3-none-any.whl (20 kB)
# Downloading pydantic-2.11.7-py3-none-any.whl (444 kB)
# Downloading pydantic_core-2.33.2-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (2.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.0/2.0 MB 62.0 MB/s eta 0:00:00
# Downloading authlib-1.6.0-py2.py3-none-any.whl (239 kB)
# Downloading google_api_python_client-2.173.0-py3-none-any.whl (13.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.6/13.6 MB 130.1 MB/s eta 0:00:00
# Downloading google_cloud_appengine_logging-1.6.2-py3-none-any.whl (16 kB)
# Using cached google_cloud_audit_log-0.3.2-py3-none-any.whl (32 kB)
# Downloading google_cloud_secret_manager-2.24.0-py3-none-any.whl (218 kB)
# Downloading google_cloud_speech-2.33.0-py3-none-any.whl (335 kB)
# Downloading graphviz-0.21-py3-none-any.whl (47 kB)
# Downloading grpc_google_iam_v1-0.14.2-py3-none-any.whl (19 kB)
# Downloading mcp-1.9.4-py3-none-any.whl (130 kB)
# Using cached tzlocal-5.3.1-py3-none-any.whl (18 kB)
# Using cached google_auth_httplib2-0.2.0-py2.py3-none-any.whl (9.3 kB)
# Using cached httplib2-0.22.0-py3-none-any.whl (96 kB)
# Downloading python_multipart-0.0.20-py3-none-any.whl (24 kB)
# Downloading sse_starlette-2.3.6-py3-none-any.whl (10 kB)
# Downloading uritemplate-4.2.0-py3-none-any.whl (11 kB)
# Using cached pyparsing-3.2.3-py3-none-any.whl (111 kB)
# Installing collected packages: uritemplate, tzlocal, python-multipart, pyparsing, pydantic-core, graphviz, cloudpickle, sse-starlette, pydantic, httplib2, google-cloud-audit-log, grpc-google-iam-v1, google-auth-httplib2, authlib, mcp, google-api-python-client, opentelemetry-resourcedetector-gcp, google-cloud-trace, google-cloud-speech, google-cloud-secret-manager, google-cloud-appengine-logging, opentelemetry-exporter-gcp-trace, google-cloud-logging, google-adk
#   Attempting uninstall: pydantic-core
#     Found existing installation: pydantic_core 2.27.2
#     Uninstalling pydantic_core-2.27.2:
#       Successfully uninstalled pydantic_core-2.27.2
#   Attempting uninstall: pydantic
#     Found existing installation: pydantic 2.10.6
#     Uninstalling pydantic-2.10.6:
#       Successfully uninstalled pydantic-2.10.6
#   Attempting uninstall: grpc-google-iam-v1
#     Found existing installation: grpc-google-iam-v1 0.12.7
#     Uninstalling grpc-google-iam-v1-0.12.7:
#       Successfully uninstalled grpc-google-iam-v1-0.12.7
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# llama-index-core 0.10.34 requires dirtyjson<2.0.0,>=1.0.8, which is not installed.
# llama-index-core 0.10.34 requires nltk<4.0.0,>=3.8.1, which is not installed.
# llama-index-core 0.10.34 requires tenacity<9.0.0,>=8.2.0, but you have tenacity 9.1.2 which is incompatible.
# chromadb 0.5.23 requires tokenizers<=0.20.3,>=0.13.2, but you have tokenizers 0.21.1 which is incompatible.
# Successfully installed authlib-1.6.0 cloudpickle-3.1.1 google-adk-0.5.0 google-api-python-client-2.173.0 google-auth-httplib2-0.2.0 google-cloud-appengine-logging-1.6.2 google-cloud-audit-log-0.3.2 google-cloud-logging-3.12.1 google-cloud-secret-manager-2.24.0 google-cloud-speech-2.33.0 google-cloud-trace-1.16.2 graphviz-0.21 grpc-google-iam-v1-0.14.2 httplib2-0.22.0 mcp-1.9.4 opentelemetry-exporter-gcp-trace-1.9.0 opentelemetry-resourcedetector-gcp-1.9.0a0 pydantic-2.11.7 pydantic-core-2.33.2 pyparsing-3.2.3 python-multipart-0.0.20 sse-starlette-2.3.6 tzlocal-5.3.1 uritemplate-4.2.0

# %%
import os
from IPython.display import JSON
import json

# Cloud project id.
PROJECT_IDS = !(gcloud config get-value core/project)
PROJECT_ID = PROJECT_IDS[0]  # @param {type:"string"}

if not PROJECT_ID:
    PROJECT_ID = str(os.environ.get("GOOGLE_CLOUD_PROJECT"))

LOCATION = "us-central1" # @param {type:"string"}

os.environ["GOOGLE_CLOUD_PROJECT"] = PROJECT_ID
os.environ["GOOGLE_CLOUD_LOCATION"] = LOCATION
os.environ["GOOGLE_GENAI_USE_VERTEXAI"] = "TRUE" # Use Vertex AI API
# [your-project-id]

# %%
import vertexai

STAGING_BUCKET = "gs://avatar-bucket-notebook"

vertexai.init(
    project=PROJECT_ID,
    location=LOCATION,
    staging_bucket=STAGING_BUCKET,
)

# %% [markdown]
# ### Create your test agent

# %%
import datetime
from zoneinfo import ZoneInfo
from google.adk.agents import Agent

def get_weather(city: str) -> dict:
    """Retrieves the current weather report for a specified city.

    Args:
        city (str): The name of the city for which to retrieve the weather report.

    Returns:
        dict: status and result or error msg.
    """
    if city.lower() == "new york":
        return {
            "status": "success",
            "report": (
                "The weather in New York is sunny with a temperature of 25 degrees"
                " Celsius (77 degrees Fahrenheit)."
            ),
        }
    else:
        return {
            "status": "error",
            "error_message": f"Weather information for '{city}' is not available.",
        }


def get_current_time(city: str) -> dict:
    """Returns the current time in a specified city.

    Args:
        city (str): The name of the city for which to retrieve the current time.

    Returns:
        dict: status and result or error msg.
    """

    if city.lower() == "new york":
        tz_identifier = "America/New_York"
    else:
        return {
            "status": "error",
            "error_message": (
                f"Sorry, I don't have timezone information for {city}."
            ),
        }

    tz = ZoneInfo(tz_identifier)
    now = datetime.datetime.now(tz)
    report = (
        f'The current time in {city} is {now.strftime("%Y-%m-%d %H:%M:%S %Z%z")}'
    )
    return {"status": "success", "report": report}


root_agent = Agent(
    name="weather_time_agent",
    model="gemini-2.0-flash",
    description=(
        "Agent to answer questions about the time and weather in a city."
    ),
    instruction=(
        "You are a helpful agent who can answer user questions about the time and weather in a city."
    ),
    tools=[get_weather, get_current_time],
)

# %% [markdown]
# ### Deploy your agent to Agent Engine¶

# %%
from vertexai import agent_engines

remote_app = agent_engines.create(
    agent_engine=root_agent,
    requirements=[
        "google-cloud-aiplatform[adk,agent_engines]"   
    ]
)
# Out:
# Deploying google.adk.agents.Agent as an application.
# Identified the following requirements: {'cloudpickle': '3.1.1', 'google-cloud-aiplatform': '1.94.0', 'pydantic': '2.11.7'}
# The following requirements are missing: {'cloudpickle', 'pydantic'}
# The following requirements are appended: {'cloudpickle==3.1.1', 'pydantic==2.11.7'}
# The final list of requirements: ['google-cloud-aiplatform[adk,agent_engines]', 'cloudpickle==3.1.1', 'pydantic==2.11.7']
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[5], line 3
#       1 from vertexai import agent_engines
# ----> 3 remote_app = agent_engines.create(
#       4     agent_engine=root_agent,
#       5     requirements=[
#       6         "google-cloud-aiplatform[adk,agent_engines]"
#       7     ]
#       8 )
#
# File ~/.local/lib/python3.12/site-packages/vertexai/agent_engines/__init__.py:147, in create(agent_engine, requirements, display_name, description, gcs_dir_name, extra_packages, env_vars)
#      61 def create(
#      62     agent_engine: Optional[Union[Queryable, OperationRegistrable]] = None,
#      63     *,
#    (...)     71     ] = None,
#      72 ) -> AgentEngine:
#      73     """Creates a new Agent Engine.
#      74
#      75     The Agent Engine will be an instance of the `agent_engine` that
#    (...)    145         nonexistent file.
#     146     """
# --> 147     return AgentEngine.create(
#     148         agent_engine=agent_engine,
#     149         requirements=requirements,
#     150         display_name=display_name,
#     151         description=description,
#     152         gcs_dir_name=gcs_dir_name,
#     153         extra_packages=extra_packages,
#     154         env_vars=env_vars,
#     155     )
#
# File ~/.local/lib/python3.12/site-packages/vertexai/agent_engines/_agent_engines.py:468, in AgentEngine.create(cls, agent_engine, requirements, display_name, description, gcs_dir_name, extra_packages, env_vars)
#     463 base.VertexAiResourceNounWithFutureManager.__init__(sdk_resource)
#     464 # Prepares the Agent Engine for creation in Vertex AI.
#     465 # This involves packaging and uploading the artifacts for
#     466 # agent_engine, requirements and extra_packages to
#     467 # `staging_bucket/gcs_dir_name`.
# --> 468 _prepare(
#     469     agent_engine=agent_engine,
#     470     requirements=requirements,
#     471     project=sdk_resource.project,
#     472     location=sdk_resource.location,
#     473     staging_bucket=staging_bucket,
#     474     gcs_dir_name=gcs_dir_name,
#     475     extra_packages=extra_packages,
#     476 )
#     477 reasoning_engine = aip_types.ReasoningEngine(
#     478     display_name=display_name,
#     479     description=description,
#     480 )
#     481 if agent_engine is not None:
#     482     # Update the package spec.
#
# File ~/.local/lib/python3.12/site-packages/vertexai/agent_engines/_agent_engines.py:1014, in _prepare(agent_engine, requirements, extra_packages, project, location, staging_bucket, gcs_dir_name)
#    1012 if agent_engine is None:
#    1013     return
# -> 1014 gcs_bucket = _get_gcs_bucket(
#    1015     project=project,
#    1016     location=location,
#    1017     staging_bucket=staging_bucket,
#    1018 )
#    1019 _upload_agent_engine(
#    1020     agent_engine=agent_engine,
#    1021     gcs_bucket=gcs_bucket,
#    1022     gcs_dir_name=gcs_dir_name,
#    1023 )
#    1024 if requirements is not None:
#
# File ~/.local/lib/python3.12/site-packages/vertexai/agent_engines/_agent_engines.py:918, in _get_gcs_bucket(project, location, staging_bucket)
#     916 staging_bucket = staging_bucket.replace("gs://", "")
#     917 try:
# --> 918     gcs_bucket = storage_client.get_bucket(staging_bucket)
#     919     _LOGGER.info(f"Using bucket {staging_bucket}")
#     920 except exceptions.NotFound:
#
# File /opt/conda/envs/py312/lib/python3.12/contextlib.py:81, in ContextDecorator.__call__.<locals>.inner(*args, **kwds)
#      78 @wraps(func)
#      79 def inner(*args, **kwds):
#      80     with self._recreate_cm():
# ---> 81         return func(*args, **kwds)
#
# File ~/.local/lib/python3.12/site-packages/google/cloud/storage/client.py:906, in Client.get_bucket(self, bucket_or_name, timeout, if_metageneration_match, if_metageneration_not_match, retry, generation, soft_deleted)
#     834 @create_trace_span(name="Storage.Client.getBucket")
#     835 def get_bucket(
#     836     self,
#    (...)    844     soft_deleted=None,
#     845 ):
#     846     """Retrieve a bucket via a GET request.
#     847
#     848     See [API reference docs](https://cloud.google.com/storage/docs/json_api/v1/buckets/get) and a [code sample](https://cloud.google.com/storage/docs/samples/storage-get-bucket-metadata#storage_get_bucket_metadata-python).
#    (...)    904             If the bucket is not found.
#     905     """
# --> 906     bucket = self._bucket_arg_to_bucket(bucket_or_name, generation=generation)
#     907     bucket.reload(
#     908         client=self,
#     909         timeout=timeout,
#    (...)    913         soft_deleted=soft_deleted,
#     914     )
#     915     return bucket
#
# File ~/.local/lib/python3.12/site-packages/google/cloud/storage/client.py:831, in Client._bucket_arg_to_bucket(self, bucket_or_name, generation)
#     829         bucket._client = self
#     830 else:
# --> 831     bucket = Bucket(self, name=bucket_or_name, generation=generation)
#     832 return bucket
#
# File ~/.local/lib/python3.12/site-packages/google/cloud/storage/bucket.py:671, in Bucket.__init__(self, client, name, user_project, generation)
#     666 def __init__(self, client, name=None, user_project=None, generation=None):
#     667     """
#     668     property :attr:`name`
#     669         Get the bucket's name.
#     670     """
# --> 671     name = _validate_name(name)
#     672     super(Bucket, self).__init__(name=name)
#     673     self._client = client
#
# File ~/.local/lib/python3.12/site-packages/google/cloud/storage/_helpers.py:144, in _validate_name(name)
#     142 # The first and last characters must be alphanumeric.
#     143 if not all([name[0].isalnum(), name[-1].isalnum()]):
# --> 144     raise ValueError("Bucket names must start and end with a number or letter.")
#     145 return name
#
# ValueError: Bucket names must start and end with a number or letter.
